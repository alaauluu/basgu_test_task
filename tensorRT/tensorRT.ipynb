# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.6 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jun 29 13:24:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/glory_results/detect/train/weights/best.pt')

model.export(format="engine")
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.4.82 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/glory_results/detect/train/weights/best.pt' with input shape (1, 3, 896, 896) BCHW and output shape(s) (1, 8, 16464) (18.3 MB)
#
# ONNX: starting export with onnx 1.22.0 opset 18...
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/head.py:189: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.dynamic or self.shape != shape:
# ONNX: slimming with onnxslim 0.1.94...
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/glory_results/detect/train/weights/best.engine")

results = model.predict(source = "/content/drive/MyDrive/test_videos/IMG_7421.MP4", stream=True, show = False, save=True)

for result in results:
  print(result.boxes)
# Out:
# Streaming output truncated to the last 5000 lines.
# xywhn: tensor([[0.5776, 0.4413, 0.0210, 0.0384],
#         [0.3609, 0.7017, 0.1185, 0.2364],
#         [0.3463, 0.7270, 0.0881, 0.1751]], device='cuda:0')
# xyxy: tensor([[725.8915, 249.8693, 752.8148, 272.6000],
#         [386.0326, 345.4285, 537.7470, 485.4013],
#         [386.9086, 378.5777, 499.7101, 482.2473]], device='cuda:0')
# xyxyn: tensor([[0.5671, 0.4221, 0.5881, 0.4605],
#         [0.3016, 0.5835, 0.4201, 0.8199],
#         [0.3023, 0.6395, 0.3904, 0.8146]], device='cuda:0')
# video 1/1 (frame 1793/2068) /content/drive/MyDrive/test_videos/IMG_7421.MP4: 896x896 1 armor, 2 military_vehicles, 21.4ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2.], device='cuda:0')
# conf: tensor([0.6569, 0.5997, 0.3091], device='cuda:0')
# data: tensor([[7.2418e+02, 2.5087e+02, 7.5168e+02, 2.7355e+02, 6.5688e-01, 0.0000e+00],
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/glory_results/detect/train/weights/best.engine")

results = model.predict(source = "/content/drive/MyDrive/test_videos/test17.mp4", stream=True, show = False, save=True)

for result in results:
  print(result.boxes)
# Out:
# Loading /content/drive/MyDrive/glory_results/detect/train/weights/best.engine for TensorRT inference...
#
# video 1/1 (frame 1/122) /content/drive/MyDrive/test_videos/test17.mp4: 896x896 3 armors, 22.9ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0.], device='cuda:0')
# conf: tensor([0.6789, 0.5435, 0.3129], device='cuda:0')
# data: tensor([[8.2789e+02, 3.2848e+02, 8.9513e+02, 3.6479e+02, 6.7889e-01, 0.0000e+00],
#         [3.4051e+02, 3.1317e+02, 4.7151e+02, 3.7006e+02, 5.4350e-01, 0.0000e+00],
#         [1.1544e+03, 4.0080e+02, 1.2032e+03, 4.6209e+02, 3.1286e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (720, 1280)
# shape: torch.Size([3, 6])
# xywh: tensor([[ 861.5084,  346.6366,   67.2377,   36.3039],
#         [ 406.0067,  341.6151,  130.9986,   56.8979],
#         [1178.8064,  431.4439,   48.8630,   61.2884]], device='cuda:0')
# xywhn: tensor([[0.6731, 0.4814, 0.0525, 0.0504],
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/glory_results/detect/train/weights/best.engine")

results = model.predict(source = "/content/drive/MyDrive/test_videos/IMG_7420.MP4", stream=True, show = False, save=True)

for result in results:
  print(result.boxes)
# Out:
# Streaming output truncated to the last 5000 lines.
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# video 1/1 (frame 1162/1517) /content/drive/MyDrive/test_videos/IMG_7420.MP4: 896x896 (no detections), 13.5ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (592, 1280)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# video 1/1 (frame 1163/1517) /content/drive/MyDrive/test_videos/IMG_7420.MP4: 896x896 (no detections), 13.5ms
# ultralytics.engine.results.Boxes object with attributes:
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/glory_results/detect/train/weights/best.engine")

results = model.predict(source = "/content/drive/MyDrive/test_videos/IMG_7419.MP4", stream=True, show = False, save=True)

for result in results:
  print(result.boxes)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (592, 1280)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# video 1/1 (frame 1495/1848) /content/drive/MyDrive/test_videos/IMG_7419.MP4: 896x896 (no detections), 13.3ms
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (592, 1280)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# ...

# %%
# !cp -r /content/runs /content/drive/MyDrive/
